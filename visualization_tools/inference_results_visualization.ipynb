# %%
from distillation.run_plot import plot_results

# %%
plot_results(study="WALT", metric="mAP50", shaded_region=False)

# %%
plot_results(study="WALT", metric="mAP50-95", shaded_region=False)

# %%
plot_results(study="WALT", metric="precision", shaded_region=False)

# %%
plot_results(study="AI-city", metric="precision", shaded_region=False)

# %%
plot_results(study="AI-city", metric="mAP50-95", shaded_region=False)
